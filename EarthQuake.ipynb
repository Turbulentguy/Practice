# %%
import pandas as pd

from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt

df = pd.read_csv('/content/sample_data/Earthquake Perception Dataset.csv', encoding='latin1')

df.head(5)
# Out:
#     age     sex marital_status        residence               education  \
# 0  21.0    Male      Unmarried           Napoli  Upper Secondary School
# 1  21.0  Female      Unmarried           Napoli  Upper Secondary School
# 2  21.0  Female      Unmarried           Napoli  Upper Secondary School
# 3  23.0    Male      Unmarried           Quarto  Upper Secondary School
# 4  64.0  Female      Unmarried  Somma Vesuviana                  Degree
#
#        occupation out_of_region_employment family_members family_disabilities  \
# 0         Student                       No              4                  No
# 1         Student                       No              5                  No
# 2  Student Worker                       No              5                  No
# 3         Student                       No              5                  No
# 4         Retired                       No              1                  No
#
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex', 'marital_status', 'residence', 'education', 'occupation',
#        'out_of_region_employment', 'family_members', 'family_disabilities',
#        'housefloor', 'house_floor', 'eartquake_num', 'earthquake80',
#        'political_orientation', 'shocks', 'fear', 'anxiety',
#        'physiological_symptoms', 'decision_timeliness', 'insomnia',
#        'seismic_concern', 'abroad', 'out_of_region',
#        'out_of_region_earthquake', 'change_of_residence',
#        'change_of_residence_earthquake', 'red_zone_frequency', 'radio_info',
#        'TV_info', 'social_media_info', 'newspaper_info', 'app_info',
#        'municipal_institutions_trust', 'regional_institutions_trust',
#        'national_institutions_trust', 'INGV_trust', 'security',
#        'reception_centers', 'property_house', 'housing_type', 'elevator',
#        'n_vehicles', 'vehicle_type', 'end_of_month', 'salary', 'salary_true'],
#       dtype='object')

# %%
df.shape
# Out:
# (474, 46)

# %%
df.isnull().sum()
# Out:
# age                                18
# sex                                 4
# marital_status                      2
# residence                           6
# education                           2
# occupation                          2
# out_of_region_employment            2
# family_members                      2
# family_disabilities                10
# housefloor                          2
# house_floor                         2
# eartquake_num                       2
# earthquake80                        2
# political_orientation             272
# shocks                              2
# fear                                2
# anxiety                             2
# physiological_symptoms              2
# decision_timeliness                 2
# insomnia                            2
# seismic_concern                     2
# abroad                              2
# out_of_region                       2
# out_of_region_earthquake            2
# change_of_residence                 2
# ...

# %% [markdown]
# 1. What is the distribution of age in the dataset?

# %%
plt.hist(df['age'] , color = 'blue')

plt.title('The Distribution of Age')

plt.xlabel('Age')

plt.ylabel('Frequency')

plt.grid(True)

plt.show()

# %% [markdown]
# 2. How is gender distributed among the respondents?

# %%
plt.bar(df['sex'].value_counts().index , df['sex'].value_counts().values , color = 'red')

plt.title('Gender Distributed Among The Respondents')

plt.xlabel('Gender')

plt.ylabel('Frequency')

plt.grid(True)

plt.show()

# %% [markdown]
# 3. What is the frequency of different marital statuses?

# %%
df['marital_status'].value_counts().to_frame()
# Out:
#                 count
# marital_status
# Unmarried         229
# Married           156
# Cohabiting         60
# Separated          11
# Divorced           11
# Widowed             5

# %% [markdown]
# 4. What is the distribution of respondents by residence?

# %%
plt.bar(df['residence'].value_counts().head(30).index , df['residence'].value_counts().head(30).values , color = 'green')

plt.title('The Distribution of Respondents By Residence')

plt.xlabel('Residence')

plt.ylabel('Frequency')

plt.xticks(rotation = 90)

plt.grid(True)

plt.show()

# %% [markdown]
# 5. How is the education level distributed in the dataset?

# %%
plt.pie(df['education'].value_counts().values , labels = df['education'].value_counts().index , autopct = '%1.1f%%')

plt.title('The Education Level Distributed')

plt.show()

# %% [markdown]
# 6. What is the most common occupation among respondents?

# %%
df['occupation'].value_counts().head(1).to_frame()
# Out:
#             count
# occupation
# Employee      169

# %% [markdown]
# 7. How many respondents are employed outside their region?

# %%
(df['out_of_region'] == 'Yes').sum()
# Out:
# 351

# %% [markdown]
# 8. What is the distribution of family members in respondents' households?

# %%
plt.bar(df['family_members'].value_counts().index , df['family_members'].value_counts().values , color = 'blue')

plt.title('The Distribution of Family Members')

plt.xlabel('Family Members')

plt.ylabel('Frequency')

plt.grid(True)

plt.show()

# %% [markdown]
# 9. How many respondents have family members with disabilities?

# %%
(df['family_disabilities'] == 'Yes').sum()
# Out:
# 42

# %% [markdown]
# 10. What is the most common floor respondents live on?

# %%
df['house_floor'].value_counts().head(1).to_frame()
# Out:
#              count
# house_floor
# 1              136

# %% [markdown]
# 11. What is the distribution of respondents by their awareness of earthquake risk?

# %%
plt.bar(df['earthquake80'].value_counts().index , df['earthquake80'].value_counts().values , color = 'red')

plt.title('The Distribution of Respondents By Their Awareness of Earthquake Risk')

plt.xlabel('Awareness of Earthquake Risk')

plt.ylabel('Frequency')

plt.grid(True)

plt.show()

# %% [markdown]
# 12. How many respondents have personal experience with earthquakes?

# %%
(df['earthquake80'] == 'Yes').sum()
# Out:
# 162

# %% [markdown]
# 13. What is the distribution of perceived earthquake intensity?

# %%
plt.bar(df['shocks'].value_counts().index , df['shocks'].value_counts().values , color = 'blue')

plt.title('The Distribution of Perceived Earthquake Intensity')

plt.xlabel('Perceived Earthquake Intensity')

plt.ylabel('Frequency')

plt.grid(True)

plt.show()

# %% [markdown]
# 14. How many respondents have attended earthquake drills?

# %%
(df['reception_centers'] == 'Yes').sum()
# Out:
# 203

# %% [markdown]
# 15. What is the distribution of respondents' trust in civil protection?

# %%
grouped = df.groupby(['municipal_institutions_trust' , 'regional_institutions_trust' , 'national_institutions_trust' , 'INGV_trust']).size().unstack()

grouped.plot(kind = 'bar' , stacked = True)

plt.title('The Distribution of Respondents\' Trust in Civil Protection')

plt.xlabel('Trust in Civil Protection')

plt.ylabel('Frequency')

plt.grid(True)

plt.show()

# %% [markdown]
# 16. How secure do respondents feel in their homes?

# %%
plt.bar(df['security'].value_counts().index , df['security'].value_counts().values , color = 'blue')

plt.title('How Secure Do Respondents Feel in Their Homes')

plt.xlabel('How Secure')

plt.ylabel('Frequency')

plt.grid(True)

plt.show()

# %% [markdown]
# 17. How many respondents live near reception centers?

# %%
(df['reception_centers'] == 'Yes').sum()
# Out:
# 203

# %% [markdown]
# 18. What is the distribution of respondents by property ownership (house)?

# %%
plt.bar(df['property_house'].value_counts().index , df['property_house'].value_counts().values , color = 'blue')

plt.title('The Distribution of Respondents by Property Ownership (House)')

plt.xlabel('Property Ownership (House)')

plt.ylabel('Frequency')

plt.grid(True)

plt.show()

# %% [markdown]
# 19. What types of housing do respondents live in?

# %%
plt.bar(df['housing_type'].value_counts().index , df['housing_type'].value_counts().values , color = 'red')

plt.title('The Types of Housing Respondents Live in')

plt.xlabel('Housing Type')

plt.ylabel('Frequency')

plt.grid(True)

plt.show()

# %% [markdown]
# 20. How many respondents have elevators in their buildings?

# %%
(df['elevator'] == 'Yes').sum()
# Out:
# 165

# %% [markdown]
# 21. What is the distribution of the number of vehicles owned by respondents?

# %%
plt.bar(df['n_vehicles'].value_counts().index , df['n_vehicles'].value_counts().values , color = 'blue')

plt.title('The Distribution of The Number of Vehicles Owned by Respondents')

plt.xlabel('The Number of Vehicles')

plt.ylabel('Frequency')

plt.grid(True)

plt.show()

# %% [markdown]
# 22. What types of vehicles do respondents own?

# %%
plt.bar(df['vehicle_type'].value_counts().index , df['vehicle_type'].value_counts().values , color = 'red')

plt.title('The Type of Vehicles Respondents Own')

plt.xlabel('Vehicle Type')

plt.ylabel('Frequency')

plt.grid(True)

plt.show()

# %% [markdown]
# 23. How do respondents' salaries distribute across different ranges?

# %%
plt.bar(df['salary'].value_counts().index , df['salary'].value_counts().values , color = 'blue')

plt.title('The Distribution of Respondents\' Salaries')

plt.xlabel('Salaries')

plt.ylabel('Frequency')

plt.xticks(rotation = 90)

plt.grid(True)

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128 (\x80) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# 24. How many respondents believe in the reliability of INGV (National Institute of Geophysics and Volcanology)?

# %%
df['INGV_trust'].sum()
# Out:
# 1655.0

# %% [markdown]
# 25. How many respondents are at home at the end of the month?

# %%
df['end_of_month'].sum()
# Out:
# 1192.0

# %% [markdown]
# 26. What is the average age of respondents?

# %%
print(f"The Average Age of Respondents : {df['age'].mean():.2f}")
# Out:
# The Average Age of Respondents : 38.87

# %% [markdown]
# 27. What is the median salary range of respondents?

# %%
print(f"The Median Salary Range of Respondents : {df['salary_true'].median():.2f}")
# Out:
# The Median Salary Range of Respondents : 21500.00

# %% [markdown]
# 28. What is the correlation between age and salary?

# %%
array = df[['age' , 'salary_true']].corr()

plt.imshow(array , aspect = 'auto' , cmap = 'coolwarm')

plt.title('The Correlation Between Age and Salary')

plt.xlabel('Age')

plt.ylabel('Salary')

plt.colorbar(label  = 'Correlation')

plt.show()

# %% [markdown]
# 29. What is the relationship between education level and salary?

# %%
education_mapping = {
    'Primary School': 1,
    'Lower Secondary School': 2,
    'Upper Secondary School': 3,
    'Degree': 4,
    'Postgraduate': 5
}

df['education_numeric'] = df['education'].map(education_mapping)

# %%
Array = df[['education_numeric' , 'salary_true']].corr()

plt.imshow(Array , aspect = 'auto' , cmap = 'coolwarm')

plt.title('The Relationship Between Education Level and Salary')

plt.xlabel('Education Level')

plt.ylabel('Salary')

plt.colorbar(label = 'Correlation')

plt.show()

# %% [markdown]
# 30. How does occupation affect perceived earthquake intensity?

# %%
Grouped = df.groupby(['occupation' , 'earthquake80']).size().unstack()

Grouped.plot(kind = 'bar' , stacked = True , color = ['blue' , 'red'])

plt.title('How Does Occupation Affect Perceived Earthquake Intensity')

plt.xlabel('Occupation')

plt.ylabel('Frequency')

plt.grid(True)

plt.show()

# %% [markdown]
# 31. Is there a relationship between gender and participation in earthquake drills?

# %%
GROUPED = df.groupby(['sex' , 'earthquake80']).size().unstack()

GROUPED.plot(kind = 'bar' , stacked = True , color = ['red' , 'blue'])

plt.title('The Relationship Between Gender and Participation in Earthquake Drills')

plt.xlabel('Gender')

plt.ylabel('Frequency')

plt.grid(True)

plt.show()

# %% [markdown]
# 32. How does family size affect perceived security in homes?

# %%
df.groupby(['family_members' , 'security']).size().unstack().plot(kind = 'bar' , stacked = True , color = ['blue' , 'red' , 'green' , 'orange' , 'cyan'])

plt.title('How Does Family Size Affect Perceived Security in Homes')

plt.xlabel('Family Size')

plt.ylabel('Security')

plt.grid(True)

plt.show()

# %% [markdown]
# 33. What is the relationship between the number of vehicles and family size?

# %%
group = df.groupby(['n_vehicles' , 'family_members']).size().unstack()

group.plot(kind = 'bar' , stacked = True , color = ['blue' , 'red' , 'lime' , 'orange' , 'cyan' , 'pink'])

plt.title('The Relationship Between the Number of Vehicles and Family Size')

plt.xlabel('Number of Vehicles')

plt.ylabel('Family Size')

plt.grid(True)

plt.show()

# %% [markdown]
# 34. How does the type of residence affect perceived earthquake risk?

# %%
df.groupby(['housing_type' , 'earthquake80']).size().unstack().plot(kind = 'bar' , stacked = True , color = ['blue' , 'red'])

plt.title('The Type of Residence Affect Perceived Earthquake Risk')

plt.xlabel('Housing Type')

plt.ylabel('Frequency')

plt.grid(True)

plt.show()

# %% [markdown]
# 35. What is the correlation between house floor and perceived earthquake intensity?

# %%
ARRAY = df[['housefloor' , 'eartquake_num']].corr()

plt.imshow(ARRAY , aspect = 'auto' , cmap = 'coolwarm')

plt.title('The Correlation Between House Floor and Perceived Earthquake Intensity')

plt.xlabel('House Floor')

plt.ylabel('Perceived Earthquake Intensity')

plt.colorbar(label = 'Correlation')

# %% [markdown]
# 36. Identify and handle missing values in the dataset.

# %%
df.isnull().sum()
# Out:
# age                                18
# sex                                 4
# marital_status                      2
# residence                           6
# education                           2
# occupation                          2
# out_of_region_employment            2
# family_members                      2
# family_disabilities                10
# housefloor                          2
# house_floor                         2
# eartquake_num                       2
# earthquake80                        2
# political_orientation             272
# shocks                              2
# fear                                2
# anxiety                             2
# physiological_symptoms              2
# decision_timeliness                 2
# insomnia                            2
# seismic_concern                     2
# abroad                              2
# out_of_region                       2
# out_of_region_earthquake            2
# change_of_residence                 2
# ...

# %%
mean_age = df['age'].mean()

df['age'].fillna(mean_age)
# Out:
# 0      21.000000
# 1      21.000000
# 2      21.000000
# 3      23.000000
# 4      64.000000
#          ...
# 469    45.000000
# 470    44.000000
# 471    32.000000
# 472    38.872807
# 473    38.872807
# Name: age, Length: 474, dtype: float64

# %%
df['sex'].dropna()
# Out:
# 0        Male
# 1      Female
# 2      Female
# 3        Male
# 4      Female
#         ...
# 467      Male
# 468    Female
# 469    Female
# 470    Female
# 471    Female
# Name: sex, Length: 470, dtype: object

# %%
df.isnull().sum()
# Out:
# age                                18
# sex                                 4
# marital_status                      2
# residence                           6
# education                           2
# occupation                          2
# out_of_region_employment            2
# family_members                      2
# family_disabilities                10
# housefloor                          2
# house_floor                         2
# eartquake_num                       2
# earthquake80                        2
# political_orientation             272
# shocks                              2
# fear                                2
# anxiety                             2
# physiological_symptoms              2
# decision_timeliness                 2
# insomnia                            2
# seismic_concern                     2
# abroad                              2
# out_of_region                       2
# out_of_region_earthquake            2
# change_of_residence                 2
# ...

# %%
columns_to_drop = ['education_numeric', 'salary']

df.drop(columns = columns_to_drop , inplace = True)

# %%
df1 = df[['marital_status', 'residence', 'education', 'occupation', 'out_of_region_employment', 'family_members', 'family_disabilities', 'housefloor', 'house_floor', 'eartquake_num', 'earthquake80', 'shocks', 'fear', 'anxiety', 'physiological_symptoms', 'decision_timeliness', 'insomnia', 'seismic_concern', 'abroad', 'out_of_region', 'out_of_region_earthquake', 'change_of_residence', 'change_of_residence_earthquake', 'red_zone_frequency', 'radio_info', 'TV_info', 'social_media_info', 'newspaper_info', 'app_info', 'municipal_institutions_trust', 'regional_institutions_trust', 'national_institutions_trust', 'INGV_trust', 'security', 'reception_centers', 'property_house', 'housing_type', 'elevator', 'n_vehicles', 'end_of_month']].dropna()

# %%
mode_political_orientation = df['political_orientation'].mode()[0]

df1 = df['political_orientation'].fillna(mode_political_orientation)

# %%
mode_vehicle_type = df['vehicle_type'].mode()[0]

df1 = df['vehicle_type'].fillna(mode_vehicle_type)

# %%
salary_mean = df['salary_true'].mean()

df1 = df['salary_true'].fillna(salary_mean)

# %% [markdown]
# 37. Check for and handle duplicate records.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# 38. Ensure all categorical variables are correctly encoded.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 474 entries, 0 to 473
# Data columns (total 45 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   age                             456 non-null    float64
#  1   sex                             470 non-null    object
#  2   marital_status                  472 non-null    object
#  3   residence                       468 non-null    object
#  4   education                       472 non-null    object
#  5   occupation                      472 non-null    object
#  6   out_of_region_employment        472 non-null    object
#  7   family_members                  472 non-null    object
#  8   family_disabilities             464 non-null    object
#  9   housefloor                      472 non-null    float64
#  10  house_floor                     472 non-null    object
#  11  eartquake_num                   472 non-null    float64
# ...

# %%
df1.isnull().sum()
# Out:
# 0

# %%
df1.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 474 entries, 0 to 473
# Series name: salary_true
# Non-Null Count  Dtype
# --------------  -----
# 474 non-null    float64
# dtypes: float64(1)
# memory usage: 3.8 KB

# %% [markdown]
# 39. Standardize the format of the 'salary' column.

# %%
mean = df['salary_true'].mean()

std = df['salary_true'].std()

df['salary_true'] = (df['salary_true'] - mean) / std

df['salary_true'].fillna(df['salary_true'].mean()).to_frame()
# Out:
#       salary_true
# 0   -8.065798e-01
# 1    1.472586e+00
# 2   -1.893057e-01
# 3   -8.065798e-01
# 4   -1.893057e-01
# ..            ...
# 469 -1.168656e-16
# 470  1.472586e+00
# 471 -1.168656e-16
# 472 -1.168656e-16
# 473 -1.168656e-16
#
# [474 rows x 1 columns]

# %% [markdown]
# 40. Convert the 'end_of_month' column to a categorical variable.

# %%
df['end_of_month'] = pd.Categorical(df['end_of_month'])

df.head(5)
# Out:
#     age     sex marital_status        residence               education  \
# 0  21.0    Male      Unmarried           Napoli  Upper Secondary School
# 1  21.0  Female      Unmarried           Napoli  Upper Secondary School
# 2  21.0  Female      Unmarried           Napoli  Upper Secondary School
# 3  23.0    Male      Unmarried           Quarto  Upper Secondary School
# 4  64.0  Female      Unmarried  Somma Vesuviana                  Degree
#
#        occupation out_of_region_employment family_members family_disabilities  \
# 0         Student                       No              4                  No
# 1         Student                       No              5                  No
# 2  Student Worker                       No              5                  No
# 3         Student                       No              5                  No
# 4         Retired                       No              1                  No
#
# ...

# %% [markdown]
# 41. Ensure consistency in the 'residence' column.

# %%
df['residence'].unique()
# Out:
# array(['Napoli', 'Quarto', 'Somma Vesuviana', 'Pollena Trocchia',
#        'Cancello Ed Arnone', 'Villaricca', 'San Giuseppe Vesuviano',
#        'Pozzuoli', 'Lusciano', 'Potenza', 'Pompei', 'Acerra',
#        'Frattaminore', 'Cirò Marina', 'Qualiano', 'Terzigno',
#        'Torre Del Greco', "Sant'Anastasia", 'Volla', 'Terni',
#        'Battipaglia', 'Vicenza', 'Roma', 'Pomigliano D\x92Arco', 'Bacoli',
#        "Capo D'orlando", 'Salerno', 'Giugliano', 'Milano', 'Cercola',
#        'Casoria', 'Messina', 'Boscoreale', 'Villa Literno', 'Modena',
#        'Piedimonte Matese', 'Torino', 'San Giorgio A Cremano',
#        'Vico Equense', 'Martina Franca', 'Caserta', 'Como', 'Caivano',
#        'Brescia', 'Varese', 'Monopoli', "Cava De' Tirreni", 'Lucca',
#        'Sant\x92Antimo', 'Catania', 'Mori', 'Cesa', 'Bagnoli', nan,
#        'Schio', 'Bergamo', 'Mugnano', 'Reggio Emilia', 'Agnano',
#        'Foligno', 'Benevento', 'Fiumicino', 'Correggio', 'Massa Lubrense',
# ...

# %% [markdown]
# 42. Check for outliers in the 'age' column.

# %%
Q1 = df['age'].quantile(0.25)

Q3 = df['age'].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR

upper = Q3 + 1.5 * IQR

df[(df['age'] < lower) | (df['age'] > upper)]
# Out:
#       age     sex marital_status residence          education occupation  \
# 306  90.0  Female        Widowed  Pozzuoli  Elementary School    Retired
#
#     out_of_region_employment family_members family_disabilities  housefloor  \
# 306                       No              1                  No         3.0
#
#      ... INGV_trust  security reception_centers property_house  housing_type  \
# 306  ...        4.0       1.0                No             No     Apartment
#
#      elevator  n_vehicles  vehicle_type  end_of_month  salary_true
# 306       Yes         0.0           NaN           2.0     -0.80658
#
# [1 rows x 45 columns]

# %% [markdown]
# 43. Verify the 'n_vehicles' values.

# %%
df['n_vehicles'].unique()
# Out:
# array([ 0.,  5.,  2.,  3.,  1.,  4., nan])

# %% [markdown]
# 44. Standardize the 'education' column.

# %%
df['education'].dropna()
# Out:
# 0      Upper Secondary School
# 1      Upper Secondary School
# 2      Upper Secondary School
# 3      Upper Secondary School
# 4                      Degree
#                 ...
# 467                    Degree
# 468    Lower Secondary School
# 469                    Degree
# 470       Postgraduate Degree
# 471                    Degree
# Name: education, Length: 472, dtype: object

# %%
df['education'].dropna().unique()
# Out:
# array(['Upper Secondary School', 'Degree', 'Postgraduate Degree',
#        'Elementary School', 'Lower Secondary School'], dtype=object)

# %% [markdown]
# 46. Check for any inconsistencies in the 'occupation' column.

# %%
df['occupation'].dropna().unique()
# Out:
# array(['Student', 'Student Worker', 'Retired', 'Employee',
#        'Self-Employed', 'Unemployed'], dtype=object)

# %% [markdown]
# 47. Ensure binary columns like 'family_disabilities' have consistent values.

# %%
df.dtypes
# Out:
# age                                float64
# sex                                 object
# marital_status                      object
# residence                           object
# education                           object
# occupation                          object
# out_of_region_employment            object
# family_members                      object
# family_disabilities                 object
# housefloor                         float64
# house_floor                         object
# eartquake_num                      float64
# earthquake80                        object
# political_orientation               object
# shocks                             float64
# fear                               float64
# anxiety                            float64
# physiological_symptoms             float64
# decision_timeliness                float64
# insomnia                           float64
# seismic_concern                    float64
# abroad                              object
# ...

# %%
df['family_disabilities'] = df['family_disabilities'].replace({'Yes' : 1 , 'No' : 0})

df['family_disabilities'].dropna().unique()
# Out:
# array([0., 1.])

# %%
df.dtypes
# Out:
# age                                float64
# sex                                 object
# marital_status                      object
# residence                           object
# education                           object
# occupation                          object
# out_of_region_employment            object
# family_members                      object
# family_disabilities                float64
# housefloor                         float64
# house_floor                         object
# eartquake_num                      float64
# earthquake80                        object
# political_orientation               object
# shocks                             float64
# fear                               float64
# anxiety                            float64
# physiological_symptoms             float64
# decision_timeliness                float64
# insomnia                           float64
# seismic_concern                    float64
# abroad                              object
# ...

# %% [markdown]
# 48. Verify the accuracy of the 'property_house' column.

# %%
df['property_house'].dropna().unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['property_house'].isnull().sum()
# Out:
# 2

# %% [markdown]
# 49. Ensure 'housing_type' values are consistent.

# %%
df['housing_type'].dropna().unique()
# Out:
# array(['Apartment', 'Other', 'Villa/Small Villa'], dtype=object)

# %% [markdown]
# 50. Standardize the format of the 'vehicle_type' column.

# %%
df.isnull().sum()
# Out:
# age                                18
# sex                                 4
# marital_status                      2
# residence                           6
# education                           2
# occupation                          2
# out_of_region_employment            2
# family_members                      2
# family_disabilities                10
# housefloor                          2
# house_floor                         2
# eartquake_num                       2
# earthquake80                        2
# political_orientation             272
# shocks                              2
# fear                                2
# anxiety                             2
# physiological_symptoms              2
# decision_timeliness                 2
# insomnia                            2
# seismic_concern                     2
# abroad                              2
# out_of_region                       2
# out_of_region_earthquake            2
# change_of_residence                 2
# ...

# %%
mode = df['vehicle_type'].mode()[0]

df['vehicle_type'] = df['vehicle_type'].fillna(mode)

df['vehicle_type']
# Out:
# 0                     Car
# 1      Car and Motorcycle
# 2                     Car
# 3                     Car
# 4                     Car
#               ...
# 469                   Car
# 470                   Car
# 471                   Car
# 472                   Car
# 473                   Car
# Name: vehicle_type, Length: 474, dtype: object

# %%
df['vehicle_type'].unique()
# Out:
# array(['Car', 'Car and Motorcycle', 'Motorcycle/Scooter'], dtype=object)

# %% [markdown]
# 51. Check for inconsistencies in the 'elevator' column.

# %%
df['elevator'].isnull().sum()
# Out:
# 2

# %%
df = df.dropna(subset = ['elevator'])

df['elevator'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['elevator'].isnull().sum()
# Out:
# 0

# %% [markdown]
# 52. Ensure 'INGV_trust' values are within the expected range.

# %%
df['INGV_trust'] = df['INGV_trust'].astype(int)

# %%
df['INGV_trust'].unique()
# Out:
# array([4, 3, 5, 1, 2])

# %%
Q1 = df['INGV_trust'].quantile(0.25)

Q3 = df['INGV_trust'].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR

upper = Q3 + 1.5 * IQR

df = df[(df['INGV_trust'] >= lower) & (df['INGV_trust'] <= upper)]

# %%
df['INGV_trust'].sort_values(ascending = True).unique()
# Out:
# array([2, 3, 4, 5])

# %% [markdown]
# 53. Validate the 'security' column values.

# %%
df['security'] = df['security'].astype(int)
# Out:
# <ipython-input-78-bd12069a09ed>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['security'] = df['security'].astype(int)

# %%
df['security'].isnull().sum()
# Out:
# 0

# %%
df['security'].sort_values(ascending = True).unique()
# Out:
# array([1, 2, 3, 4, 5])

# %% [markdown]
# 54. Check for and handle inconsistencies in the 'reception_centers' column.

# %%
df['reception_centers'].isnull().sum()
# Out:
# 0

# %%
df['reception_centers'].sort_values(ascending = False).unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# 55. Standardize 'out_of_region_employment' values.

# %%
df['out_of_region_employment'].isnull().sum()
# Out:
# 0

# %%
df['out_of_region_employment'].sort_values(ascending = False).unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# 56. Verify the 'end_of_month' values.

# %%
df['end_of_month'] = df['end_of_month'].astype(int)
# Out:
# <ipython-input-85-47abbe458093>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end_of_month'] = df['end_of_month'].astype(int)

# %%
df['end_of_month'].isnull().sum()
# Out:
# 0

# %%
df['end_of_month'].sort_values(ascending = True).unique()
# Out:
# array([1, 2, 3, 4, 5])

# %% [markdown]
# 57. Ensure all 'yes/no' columns have consistent values.

# %%
df[['abroad' , 'out_of_region' , 'out_of_region_earthquake' , 'change_of_residence' , 'change_of_residence_earthquake' , 'red_zone_frequency']].isnull().sum()
# Out:
# abroad                            0
# out_of_region                     0
# out_of_region_earthquake          0
# change_of_residence               0
# change_of_residence_earthquake    0
# red_zone_frequency                0
# dtype: int64

# %% [markdown]
# 58. Normalize the 'salary' column for uniform analysis.

# %%
df['salary_true'].isnull().sum()
# Out:
# 163

# %%
mean = df['salary_true'].mean()

df['salary_true'] = df['salary_true'].fillna(mean)

# %% [markdown]
# 59. Create a histogram of the age distribution.

# %%
plt.hist(df['age'] , bins = 10 , color = 'blue')

plt.title('The Age Distribution')

plt.xlabel('Age')

plt.ylabel('Frequency')

plt.grid(True)

plt.show()

# %% [markdown]
# 60. Plot the gender distribution using a bar chart.

# %%
plt.bar(df['sex'].value_counts().index , df['sex'].value_counts().values , color = 'blue')

plt.title('The Gender Distribution')

plt.xlabel('Gender')

plt.ylabel('Frequency')

plt.grid(True)

plt.show()

# %% [markdown]
# 61. Visualize the frequency of different marital statuses.

# %%
plt.pie(df['marital_status'].value_counts().values , labels = df['marital_status'].value_counts().index , autopct = '%1.1f%%')

plt.title('The Frequency of Different Marital Statuses')

plt.legend(loc = 'best')

plt.show()

# %% [markdown]
# 62. Plot the education level distribution using a pie chart.

# %%
plt.pie(df['education'].value_counts().values , labels = df['education'].value_counts().index , autopct = "%1.1f%%")

plt.title('The Education Level Distribution')

plt.show()

# %% [markdown]
# 63. Create a bar chart of the most common occupations.

# %%
df
# Out:
#       age     sex marital_status         residence               education  \
# 0    21.0    Male      Unmarried            Napoli  Upper Secondary School
# 1    21.0  Female      Unmarried            Napoli  Upper Secondary School
# 2    21.0  Female      Unmarried            Napoli  Upper Secondary School
# 4    64.0  Female      Unmarried   Somma Vesuviana                  Degree
# 5    22.0  Female      Unmarried  Pollena Trocchia  Upper Secondary School
# ..    ...     ...            ...               ...                     ...
# 467  25.0    Male      Unmarried           Caserta                  Degree
# 468   NaN  Female      Unmarried           Cercola  Lower Secondary School
# 469  45.0  Female      Unmarried          Pozzuoli                  Degree
# 470  44.0  Female     Cohabiting          Pozzuoli     Postgraduate Degree
# 471  32.0  Female        Married         Gualtieri                  Degree
#
#          occupation out_of_region_employment family_members  \
# ...

# %%
plt.bar(df['occupation'].value_counts().index , df['occupation'].value_counts().values , color = 'blue')

plt.title('The Most Common Occupations')

plt.xlabel('Occupation')

plt.xticks(rotation = 90)

plt.ylabel('Frequency')

plt.grid(True)

plt.show()

# %% [markdown]
# 64. Visualize the number of respondents employed outside their region.

# %%
plt.bar(df['out_of_region_employment'].value_counts().index , df['out_of_region_employment'].value_counts().values , color = 'red')

plt.title('The Number of Respondents Employed Outside Their Region')

plt.xlabel('Out of Region Employment')

plt.ylabel('Frequency')

plt.grid(True)

plt.show()

# %% [markdown]
# 65. Plot the distribution of family members using a histogram.

# %%
plt.hist(df['family_members'])

plt.title('The Distribution of Family Members')

plt.xlabel('Family Members')

plt.ylabel('Frequency')

plt.grid(True)

plt.show()

# %% [markdown]
# 66. Create a bar chart of family members with disabilities.

# %%
grouped = df.groupby(['family_members' , 'family_disabilities']).size().unstack()

grouped.plot(kind = 'bar' , stacked = True , color = ['blue' , 'red'])

plt.title('Family Members with Disabilities')

plt.xlabel('Family Members')

plt.ylabel('Frequency')

plt.grid(True)

plt.show()

# %% [markdown]
# 67. Visualize the house floor distribution using a bar chart.

# %%
plt.bar(df['housefloor'].value_counts().index , df['housefloor'].value_counts().values , color = 'blue')

plt.title('The House Floor Distribution')

plt.xlabel('House Floor')

plt.ylabel('Frequency')

plt.grid(True)

plt.show()

# %% [markdown]
# 68. Plot the awareness of earthquake risk using a pie chart.

# %%
plt.pie(df['earthquake80'].value_counts().values , labels = df['earthquake80'].value_counts().index , autopct = '%1.1f%%')

plt.title('The Awareness of Earthquake Risk')

plt.legend()

plt.show()

# %% [markdown]
# 69. Create a bar chart of personal earthquake experiences.

# %%
plt.bar(df['shocks'].value_counts().index , df['shocks'].value_counts().values , color = 'blue')

plt.title('Personal Earthquake Experiences')

plt.xlabel('Shock')

plt.ylabel('Frequency')

plt.grid(True)

plt.show()

# %% [markdown]
# 70. Visualize perceived earthquake intensity using a histogram.

# %%
plt.hist(df['earthquake80'])

plt.title('Perceived Earthquake Intensity')

plt.xlabel('Earthquake Intensity')

plt.ylabel('Frequency')

plt.grid(True)

plt.show()
